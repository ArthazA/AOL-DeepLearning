# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt") 
print("Starting training...")
results = model.train(
    data="./FNVdataset/data.yaml", 
    epochs=30, 
    imgsz=640,
    device=0, 
    name="FNV_model"
)
    
print("Training complete!")
# Out:
# Starting training...
# Ultralytics 8.3.237  Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# ...
