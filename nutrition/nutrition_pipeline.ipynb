# %%
import json

with open("nutrition_per_100g.json") as f:
    nutrition_100g = json.load(f)

with open("avg_weights.json") as f:
    avg_weights = json.load(f)

# %%
def compute_nutrition(counts):
    summary = {}
    totals = {"calories": 0, "carbs": 0, "protein": 0, "fat": 0, "fiber": 0}

    for item, count in counts.items():
        weight = avg_weights[item] * count
        factor = weight / 100
        per100 = nutrition_100g[item]

        summary[item] = {
            "count": count,
            "weight_g": weight,
            "calories": per100["calories"] * factor,
            "carbs": per100["carbs"] * factor,
            "protein": per100["protein"] * factor,
            "fat": per100["fat"] * factor,
            "fiber": per100["fiber"] * factor
        }

        for k in totals:
            totals[k] += summary[item][k]

    return summary, totals

# %%
summary, totals = compute_nutrition({'Apple': 2, 'Banana': 1})
summary, totals
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 summary, totals = compute_nutrition({'Apple': 2, 'Banana': 1})
#       2 summary, totals
#
# Cell In[5], line 8, in compute_nutrition(counts)
#       6 weight = avg_weights[item] * count
#       7 factor = weight / 100
# ----> 8 per100 = nutrition_100g[item]
#      10 summary[item] = {
#      11     "count": count,
#      12     "weight_g": weight,
#    (...)
#      17     "fiber": per100["fiber"] * factor
#      18 }
#      20 for k in totals:
#
# KeyError: 'Apple'
