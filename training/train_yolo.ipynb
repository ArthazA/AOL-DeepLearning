# %%
from ultralytics import YOLO
from pathlib import Path

# %%
import torch
print(torch.__version__)
print(torch._dynamo)

# %%
def main():
    PROJECT_ROOT = Path.cwd().parent

    DATA_YAML = PROJECT_ROOT / "data" / "FNVdataset_correct" / "data.yaml"
    RUNS_DIR = PROJECT_ROOT / "runs"

    model = YOLO("yolov8s.pt")

    model.train(
        data=str(DATA_YAML),
        epochs=10,
        imgsz=640,
        batch=-1,
        optimizer="AdamW",
        lr0=1e-3,
        cos_lr=True,
        weight_decay=5e-4,

        label_smoothing=0.05,
        patience=20,

        hsv_h=0.015,
        hsv_s=0.7,
        hsv_v=0.4,
        degrees=5.0,
        translate=0.1,
        scale=0.5,
        shear=0.0,
        flipud=0.0,
        fliplr=0.5,
        mosaic=0.5,
        mixup=0.0,

        workers=8,
        device=0,
        amp=True,

        # freeze=10,

        project=str(RUNS_DIR),
        name="yolov11_fnv_correct_p1",
        exist_ok=False
    )

    print("\nTraining completed successfully.")
    print("Best model saved in:")
    print(RUNS_DIR / "yolov11_fruit_veg" / "weights" / "best.pt")


if __name__ == "__main__":
    main()
# Out:
# WARNING 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.3.237  Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=c:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\data.yaml, degrees=5.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=0.5, multi_scale=False, name=yolov11_fnv_correct_p12, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=c:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\runs\yolov11_fnv_correct_p12, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=41
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2131915  ultralytics.nn.modules.head.Detect           [41, [128, 256, 512]]
# Model summary: 129 layers, 11,151,467 parameters, 11,151,451 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 620.7322.3 MB/s, size: 43.6 KB)
# train: Scanning C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\train\labels.cache... 8499 images, 145 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 8499/8499 7.0Mit/s 0.0s
# train: C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\train\images\img-6400-_jpg.rf.8ee60ecbdfcee41ccc9a14b8ab4cf2c7.jpg: 1 duplicate labels removed
# train: C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\train\images\img-6546-_jpg.rf.a5ec341d4257be2eb80f55383434d463.jpg: 1 duplicate labels removed
# train: C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\train\images\img-9790-_jpg.rf.ab11d1d4439a88c915671588043b5c13.jpg: 1 duplicate labels removed
# WARNING Box and segment counts should be equal, but got len(segments) = 13510, len(boxes) = 37686. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# AutoBatch: Computing optimal batch size for imgsz=640 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (NVIDIA GeForce RTX 3060) 12.00G total, 0.53G reserved, 0.20G allocated, 11.27G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     11151467       28.73         1.028         83.89         16.01        (1, 3, 640, 640)                    list
#     11151467       57.47         1.325         20.46         20.19        (2, 3, 640, 640)                    list
#     11151467       114.9         1.929         41.42         43.01        (4, 3, 640, 640)                    list
#     11151467       229.9         3.053         43.14         58.35        (8, 3, 640, 640)                    list
#     11151467       459.7         5.086         115.6         109.5       (16, 3, 640, 640)                    list
# AutoBatch: Using batch-size 22 for CUDA:0 7.48G/12.00G (62%)
# train: Fast image access  (ping: 0.00.0 ms, read: 890.5490.2 MB/s, size: 53.8 KB)
# train: Scanning C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\train\labels.cache... 8499 images, 145 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 8499/8499  0.0s
# train: C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\train\images\img-6400-_jpg.rf.8ee60ecbdfcee41ccc9a14b8ab4cf2c7.jpg: 1 duplicate labels removed
# train: C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\train\images\img-6546-_jpg.rf.a5ec341d4257be2eb80f55383434d463.jpg: 1 duplicate labels removed
# train: C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\train\images\img-9790-_jpg.rf.ab11d1d4439a88c915671588043b5c13.jpg: 1 duplicate labels removed
# WARNING Box and segment counts should be equal, but got len(segments) = 13510, len(boxes) = 37686. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.10.0 ms, read: 116.038.9 MB/s, size: 57.0 KB)
# val: Scanning C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\valid\labels.cache... 1479 images, 23 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1479/1479 1.1Mit/s 0.0s
# val: C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\valid\images\img-5810-_jpg.rf.f41f9072a362d6f056c8ff4c91cdccac.jpg: 6 duplicate labels removed
# val: C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\valid\images\img-677-_jpg.rf.a7331de4d2567e92be4b92f1437c245f.jpg: 1 duplicate labels removed
# val: C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\data\FNVdataset_correct\valid\images\img-7160-_jpg.rf.7c240f5715eba7fc5dd34a5bf14f3995.jpg: 1 duplicate labels removed
# WARNING Box and segment counts should be equal, but got len(segments) = 2406, len(boxes) = 6571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to C:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\runs\yolov11_fnv_correct_p12\labels.jpg...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 51
#      47     print(RUNS_DIR / "yolov11_fruit_veg" / "weights" / "best.pt")
#      50 if __name__ == "__main__":
# ---> 51     main()
#
# Cell In[4], line 9, in main()
#       5 RUNS_DIR = PROJECT_ROOT / "runs"
#       7 model = YOLO("yolov8s.pt")
# ----> 9 model.train(
#      10     data=str(DATA_YAML),
#      11     epochs=10,
#      12     imgsz=640,
#      13     batch=-1,
#      14     optimizer="AdamW",
#      15     lr0=1e-3,
#      16     cos_lr=True,
#      17     weight_decay=5e-4,
#      18
#      19     label_smoothing=0.05,
#      20     patience=20,
#      21
#      22     hsv_h=0.015,
#      23     hsv_s=0.7,
#      24     hsv_v=0.4,
#      25     degrees=5.0,
#      26     translate=0.1,
#      27     scale=0.5,
#      28     shear=0.0,
#      29     flipud=0.0,
#      30     fliplr=0.5,
#      31     mosaic=0.5,
#      32     mixup=0.0,
#      33
#      34     workers=8,
#      35     device=0,
#      36     amp=True,
#      37
#      38     # freeze=10,
#      39
#      40     project=str(RUNS_DIR),
#      41     name="yolov11_fnv_correct_p1",
#      42     exist_ok=False
#      43 )
#      45 print("\nTraining completed successfully.")
#      46 print("Best model saved in:")
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\ultralytics\engine\model.py:773, in Model.train(self, trainer, **kwargs)
#     770     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     771     self.model = self.trainer.model
# --> 773 self.trainer.train()
#     774 # Update model and cfg after training
#     775 if RANK in {-1, 0}:
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\ultralytics\engine\trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\ultralytics\engine\trainer.py:364, in BaseTrainer._do_train(self)
#     362 if self.world_size > 1:
#     363     self._setup_ddp()
# --> 364 self._setup_train()
#     366 nb = len(self.train_loader)  # number of batches
#     367 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\ultralytics\engine\trainer.py:345, in BaseTrainer._setup_train(self)
#     343 weight_decay = self.args.weight_decay * self.batch_size * self.accumulate / self.args.nbs  # scale weight_decay
#     344 iterations = math.ceil(len(self.train_loader.dataset) / max(self.batch_size, self.args.nbs)) * self.epochs
# --> 345 self.optimizer = self.build_optimizer(
#     346     model=self.model,
#     347     name=self.args.optimizer,
#     348     lr=self.args.lr0,
#     349     momentum=self.args.momentum,
#     350     decay=weight_decay,
#     351     iterations=iterations,
#     352 )
#     353 # Scheduler
#     354 self._setup_scheduler()
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\ultralytics\engine\trainer.py:957, in BaseTrainer.build_optimizer(self, model, name, lr, momentum, decay, iterations)
#     955 name = {x.lower(): x for x in optimizers}.get(name.lower())
#     956 if name in {"Adam", "Adamax", "AdamW", "NAdam", "RAdam"}:
# --> 957     optimizer = getattr(optim, name, optim.Adam)(g[2], lr=lr, betas=(momentum, 0.999), weight_decay=0.0)
#     958 elif name == "RMSProp":
#     959     optimizer = optim.RMSprop(g[2], lr=lr, momentum=momentum)
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\torch\optim\adamw.py:77, in AdamW.__init__(self, params, lr, betas, eps, weight_decay, amsgrad, maximize, foreach, capturable, differentiable, fused)
#      64     raise ValueError(f"Invalid weight_decay value: {weight_decay}")
#      65 defaults = dict(
#      66     lr=lr,
#      67     betas=betas,
#    (...)
#      75     fused=fused,
#      76 )
# ---> 77 super().__init__(params, defaults)
#      79 if fused:
#      80     if differentiable:
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\torch\optim\optimizer.py:371, in Optimizer.__init__(self, params, defaults)
#     368     param_groups = [{"params": param_groups}]
#     370 for param_group in param_groups:
# --> 371     self.add_param_group(cast(dict, param_group))
#     373 # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     374 # which I don't think exists
#     375 # https://github.com/pytorch/pytorch/issues/72948
#     376 self._warned_capturable_if_run_uncaptured = True
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\torch\_compile.py:27, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      25 disable_fn = getattr(fn, "__dynamo_disable", None)
#      26 if disable_fn is None:
# ---> 27     import torch._dynamo
#      29     disable_fn = torch._dynamo.disable(fn, recursive)
#      30     fn.__dynamo_disable = disable_fn
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\torch\_dynamo\__init__.py:3
#       1 import torch
# ----> 3 from . import convert_frame, eval_frame, resume_execution
#       4 from .backends.registry import list_backends, lookup_backend, register_backend
#       5 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\torch\_dynamo\convert_frame.py:53
#      47 from torch.utils._python_dispatch import (
#      48     _disable_current_modes,
#      49     is_in_torch_dispatch_mode,
#      50 )
#      51 from torch.utils._traceback import CapturedTraceback, format_traceback_short
# ---> 53 from . import config, exc, trace_rules
#      54 from .bytecode_analysis import remove_dead_code, remove_pointless_jumps
#      55 from .bytecode_transformation import (
#      56     check_inst_exn_tab_entries_valid,
#      57     Instruction,
#    (...)
#      60     transform_code_object,
#      61 )
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\torch\_dynamo\trace_rules.py:46
#      44 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      45 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 46 from .variables import (
#      47     BuiltinVariable,
#      48     FunctionalCallVariable,
#      49     FunctorchHigherOrderVariable,
#      50     NestedUserFunctionVariable,
#      51     PolyfilledFunctionVariable,
#      52     SkipFunctionVariable,
#      53     TorchInGraphFunctionVariable,
#      54     UserFunctionVariable,
#      55     UserMethodVariable,
#      56 )
#      59 np: Optional[types.ModuleType] = None
#      60 try:
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\torch\_dynamo\variables\__init__.py:104
#      95 from .sdpa import SDPAParamsVariable
#      96 from .tensor import (
#      97     FakeItemVariable,
#      98     NumpyNdarrayVariable,
#    (...)
#     102     UntypedStorageVariable,
#     103 )
# --> 104 from .torch import TorchCtxManagerClassVariable, TorchInGraphFunctionVariable
#     105 from .user_defined import (
#     106     MutableMappingVariable,
#     107     RemovableHandleVariable,
#    (...)
#     110     WeakRefVariable,
#     111 )
#     114 __all__ = [
#     115     "AutogradFunctionContextVariable",
#     116     "AutogradFunctionVariable",
#    (...)
#     178     "WithExitFunctionVariable",
#     179 ]
#
# File c:\Users\user\anaconda3\envs\dietary_estimation\lib\site-packages\torch\_dynamo\variables\torch.py:142
#     132 # Convert to dict for O(1) access times
#     133 constant_fold_functions = dict.fromkeys(constant_fold_functions)
#     136 tracing_state_functions = {
#     137     torch.jit.is_scripting: False,
#     138     torch.jit.is_tracing: False,
#     139     torch._C._get_tracing_state: None,
#     140     torch.fx._symbolic_trace.is_fx_tracing: False,
#     141     torch.onnx.is_in_onnx_export: False,
# --> 142     torch._dynamo.external_utils.is_compiling: True,
#     143     torch._utils.is_compiling: True,
#     144     torch.compiler.is_compiling: True,
#     145     torch.compiler.is_dynamo_compiling: True,
#     146     torch.nn.modules.activation._is_make_fx_tracing: False,
#     147 }
#     149 bin_ops = dict.fromkeys(["add", "sub", "mul", "div", "sqrt"])
#     152 class BaseTorchVariable(VariableTracker):
#
# AttributeError: partially initialized module 'torch._dynamo' has no attribute 'external_utils' (most likely due to a circular import)
