# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO("../runs/yolov11_fruit_veg/weights/best.pt")

results = model("../data/FNVdataset/test/images", conf=0.4)
# Out:
# image 1/20 c:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\training\..\data\FNVdataset\test\images\img-9574-_jpg.rf.607f58f3c3573661d61e4e3abcf3b983.jpg: 640x640 7 0s, 6.5ms
# image 2/20 c:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\training\..\data\FNVdataset\test\images\img-9580-_jpg.rf.660d3197f028e76d41ac62813deeb89d.jpg: 640x640 3 0s, 6.9ms
# image 3/20 c:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\training\..\data\FNVdataset\test\images\img-9585-_jpg.rf.4462bf5af74093764b586b253e7590d9.jpg: 640x640 3 0s, 6.7ms
# image 4/20 c:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\training\..\data\FNVdataset\test\images\img-9635-_jpg.rf.5a6d51c037251f8c2e278de7a7cb2f45.jpg: 640x640 7 0s, 6.4ms
# image 5/20 c:\Users\user\OneDrive - Bina Nusantara\Sem 5\AOL-DeepLearning\training\..\data\FNVdataset\test\images\img-97-_jpg.rf.4c6ef412d6eab1ae0dc323a3f548f05c.jpg: 640x640 1 0, 7.3ms
# ...

# %%
for r in results[:5]:
    img = r.plot()
    plt.imshow(img)
    plt.axis("off")
    plt.show()
